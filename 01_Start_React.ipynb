# %% [markdown]
# ## 1.1 왜 리액트인가?
# - 한때 자바스크립트는 단순한 스크립트 언어에 불과했지만, 현재는 웹 애플리케이션에서 가장 핵심적인 역할을 한다.
# - 영역을 확장하여 서버 사이드는 물론 모바일, 데스크톱 애플리케이션에서도 활약한다.
# - 페이스북 개발 팀이 최대한 성능을 아끼고 편안한 사용자 경험을 제공하면서 구현하고자 개발한 것이 리액트이다.
#
# #### 1.1.1.1 리액트 이해
# - 리액트는 자바스크립트 라이브러리로 사용자 인터페이스를 만드는 데 사용합니다.
# - 다른 프레임워크와 달리, 오직 V(view)만 신경 쓰는 라이브러리
#
# - 컴포넌트
#     - 리액트 프로젝트에서 특정 부분이 어떻게 생길지 정하는 선언체
#     - 재사용이 가능한 API로 수많은 기능들을 내장하고 있으며, 컴포넌트 하나에서 해당 컴포넌트의 생김새와 작동 방식을 정의.
#
# - 랜더링
#     - 사용자 화면에 뷰를 보여 주는 것
#
# - 초기 렌더링
#     - 맨 처음에 어떻게 보일지를 정하는 초기 렌더링
#         ```js
#         render() {...}
#         ```
#     - 컴포넌트가 어떻게 생겼는지 정의하는 역할
#     - html 형식의 문자열을 반환하지 않고, 객체를 반환
#
# - 조화 과정
#     -컴포넌트에서 데이터에 변화가 있을 때 우리가 보기에는 변화에 따라 뷰가 변형되는 것 처럼 보이지만, 새로운 요소로 갈아 끼우기 때문에 업데이트 과정을 거친다 보다는 조화 과정을 거친다가 정확한 표현

# %% [markdown]
# ## 1.2 리액트의 특징
# ### 1.2.1 Virtual DOM
# - 리액트의 주요 특징 중 하나는 Virtual DOM을 사용
#
# #### 1.2.1.1 DOM이란
# - DOM은 Document Object Model의 약서, 객체로 문서 구조를 표현하는 방법으로 XML이나 HTMl로 작성한다.
# - DOM은 느린가?
#     - DOM은 동적 UI에 최적화 되어 있지 않다.
#     - 규모가 큰 웹 애플리케이션에서 DOM에 직접 접근하여 변화를 주다 보면 성능 이슈가 조금씩 발생해 느려진다.
#     - DOM 자체는 빠른데 웹 브라우저 단에서 DOM변화가 일어나면 웹 브라우저가 CSS를 다시 연산하고, 레이아웃을 구성하고, 페이지를 리페인트한다. 이 과정에서 시간이 허비된다.
#
# - 해결법
#     - DOM을 최소한으로 조작하여 작업을 처리하는 방식으로 개선
#     - 리액트는 Virtual DOM 방식을 사용하여 DOM 업데이트를 추상화함으로써 DOM 처리 횟수를 최소화하고 효율적으로 진행
#
# #### 1.2.1.2 Virtual DOM
#     - Virtual DOM을 사용하면 실제 DOM에 접근하여 조작하는대신, 이를 추상화한 자바스크립트 객체를 구성하여 사용한다.
#     - 리액트에서 데이터가 변하여 웹 브라우저에 실제 DOM을 업데이트 할때 세 가지 절차
#         1. 데이터를 업데이트하면 전체 UI를 Virtual DOM에 리렌더링한다.
#         2. 이전 Virtual DOM에 있던 내용과 현재 내용을 비교.
#         3. 바뀐 부분만 실제 DOM에 적용.
#     - Virtual DOM을 사용한다고 사용하지 않을 때와 비교해 무조건 빠른 것은 아니다.

# %% [markdown]
# ## 1.3 작업 환경 설정
# 1. Node.js / npm, yarn 설치하기
# 2. 코드 에디터 설치하기
# 3. Git 설치하기
# 4. 프로젝트 만들기
#
# 리엑트 실행
# ![image.png](attachment:image.png)
